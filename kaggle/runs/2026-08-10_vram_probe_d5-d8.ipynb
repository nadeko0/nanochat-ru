# %% [markdown]
# # VRAM probe -- find the largest --device-batch-size before committing hours of training
#
# Uses `kaggle/vram_probe.py`, which builds the real GPT model + real Muon/AdamW optimizer
# (same as `scripts/base_train.py`) and searches for the largest batch size that avoids a CUDA
# OOM, via `accelerate.utils.find_executable_batch_size` (handles cache-clearing between OOM
# retries -- a naive retry loop without that gets false negatives from memory fragmentation).
#
# Runs in a couple of minutes per depth tested (torch.compile warmup dominates, not the actual
# search) -- cheap way to de-risk a multi-hour run before starting it.
#
# Upload via File -> Upload Notebook. T4 x2 accelerator (only GPU 0 is used -- see markdown
# on Cell 2 for why one GPU is representative), internet access for `pip install accelerate`
# and cloning the repo. No Kaggle Secrets needed -- this doesn't touch Google Drive.

# %% [markdown]
# ## Cell 1: clone repo, install dependencies

# %%
import os
import subprocess
import sys

REPO_URL = "https://github.com/nadeko0/nanochat-ru.git"
REPO_DIR = "/kaggle/working/repo"

if os.path.isdir(os.path.join(REPO_DIR, ".git")):
    print("Repo already present, pulling latest...")
    # !git -C {REPO_DIR} pull
else:
    # !git clone {REPO_URL} {REPO_DIR}

os.chdir(REPO_DIR)

def have(cmd):
    return subprocess.run(["bash", "-lc", f"command -v {cmd}"], capture_output=True).returncode == 0

if not have("uv"):
    # !curl -LsSf https://astral.sh/uv/install.sh | sh
os.environ["PATH"] = f"{os.path.expanduser('~/.local/bin')}:{os.environ['PATH']}"

if not have("cargo"):
    # !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y
os.environ["PATH"] = f"{os.path.expanduser('~/.cargo/bin')}:{os.environ['PATH']}"

# !uv pip install --system --python {sys.executable} --extra gpu -r pyproject.toml
# !uv pip install --system --python {sys.executable} accelerate

print("Cell 1 done.")
# Out:
# Repo already present, pulling latest...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 767 bytes | 767.00 KiB/s, done.
# From https://github.com/nadeko0/nanochat-ru
#    6830dc0..7955b9c  master     -> origin/master
# Updating 6830dc0..7955b9c
# Fast-forward
#  kaggle/vram_probe.py | 8 ++++++++
#  1 file changed, 8 insertions(+)
# Using Python 3.12.13 environment at: /usr
# Resolved 84 packages in 65ms
# Checked 84 packages in 1ms
# Using Python 3.12.13 environment at: /usr
# Checked 1 package in 18ms
# Cell 1 done.

# %% [markdown]
# ## Cell 2: probe candidate depths
#
# Only uses GPU 0 -- DDP (what `base_train.py` actually uses across both T4s) replicates the
# full model + optimizer state onto *each* GPU independently, so per-GPU memory usage depends
# on the local (per-device) batch size, not on how many GPUs are in the job. Testing on one GPU
# gives the same answer as testing under `torchrun --nproc_per_node=2`, for a fraction of the
# setup cost.
#
# Edit `DEPTHS_TO_TEST` to whatever you're actually considering.

# %%
import os

os.chdir("/kaggle/working/repo")
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

DEPTHS_TO_TEST = [5, 6, 7, 8]

for depth in DEPTHS_TO_TEST:
    print(f"\n{'='*60}\nProbing depth={depth}\n{'='*60}")
    # !python kaggle/vram_probe.py --depth={depth} --max-seq-len=2048 --starting-batch-size=32
# Out:
# ============================================================
# Probing depth=5
# ============================================================
# depth=5 model_dim=384 n_head=3
# Scaling the LR for the AdamW parameters ∝1/√(384/768) = 1.414214
# W0810 18:33:17.874000 304 torch/_inductor/utils.py:1613] [0/0] Not enough SMs to use max_autotune_gemm mode
# W0810 18:35:45.684000 304 torch/_dynamo/convert_frame.py:1358] [0/8] torch._dynamo hit config.recompile_limit (8)
# W0810 18:35:45.684000 304 torch/_dynamo/convert_frame.py:1358] [0/8]    function: 'forward' (/kaggle/working/repo/nanochat/gpt.py:459)
# W0810 18:35:45.684000 304 torch/_dynamo/convert_frame.py:1358] [0/8]    last reason: 0/7: tensor 'idx' size mismatch at index 0. expected 13, actual 11
# W0810 18:35:45.684000 304 torch/_dynamo/convert_frame.py:1358] [0/8] To log all recompilation reasons, use TORCH_LOGS="recompiles".
# W0810 18:35:45.684000 304 torch/_dynamo/convert_frame.py:1358] [0/8] To diagnose recompilation issues, see https://pytorch.org/docs/main/torch.compiler_troubleshooting.html
#   batch_size=8 OK, peak memory: 11465 MiB
#
# Largest working --device-batch-size for depth=5, max-seq-len=2048: 8
# Peak memory at that batch size: 11465 MiB / 14912 MiB
#
# ============================================================
# Probing depth=6
# ============================================================
# depth=6 model_dim=384 n_head=3
# Scaling the LR for the AdamW parameters ∝1/√(384/768) = 1.414214
# W0810 18:36:07.082000 4223 torch/_inductor/utils.py:1613] [0/0] Not enough SMs to use max_autotune_gemm mode
#   batch_size=13 OK, peak memory: 11667 MiB
#
# Largest working --device-batch-size for depth=6, max-seq-len=2048: 13
# Peak memory at that batch size: 11667 MiB / 14912 MiB
#
# ============================================================
# Probing depth=7
# ============================================================
# depth=7 model_dim=512 n_head=4
# Scaling the LR for the AdamW parameters ∝1/√(512/768) = 1.224745
# W0810 18:38:52.926000 6585 torch/_inductor/utils.py:1613] [0/0] Not enough SMs to use max_autotune_gemm mode
# W0810 18:41:04.433000 6585 torch/_dynamo/convert_frame.py:1358] [0/8] torch._dynamo hit config.recompile_limit (8)
# W0810 18:41:04.433000 6585 torch/_dynamo/convert_frame.py:1358] [0/8]    function: 'forward' (/kaggle/working/repo/nanochat/gpt.py:459)
# W0810 18:41:04.433000 6585 torch/_dynamo/convert_frame.py:1358] [0/8]    last reason: 0/7: tensor 'idx' size mismatch at index 0. expected 13, actual 11
# W0810 18:41:04.433000 6585 torch/_dynamo/convert_frame.py:1358] [0/8] To log all recompilation reasons, use TORCH_LOGS="recompiles".
# W0810 18:41:04.433000 6585 torch/_dynamo/convert_frame.py:1358] [0/8] To diagnose recompilation issues, see https://pytorch.org/docs/main/torch.compiler_troubleshooting.html
#   batch_size=6 OK, peak memory: 10889 MiB
#
# Largest working --device-batch-size for depth=7, max-seq-len=2048: 6
# Peak memory at that batch size: 10889 MiB / 14912 MiB
#
# ============================================================
# Probing depth=8
# ============================================================
# depth=8 model_dim=512 n_head=4
# Scaling the LR for the AdamW parameters ∝1/√(512/768) = 1.224745
# W0810 18:41:49.441000 9563 torch/_inductor/utils.py:1613] [0/0] Not enough SMs to use max_autotune_gemm mode
# W0810 18:44:08.304000 9563 torch/_dynamo/convert_frame.py:1358] [0/8] torch._dynamo hit config.recompile_limit (8)
# W0810 18:44:08.304000 9563 torch/_dynamo/convert_frame.py:1358] [0/8]    function: 'forward' (/kaggle/working/repo/nanochat/gpt.py:459)
# W0810 18:44:08.304000 9563 torch/_dynamo/convert_frame.py:1358] [0/8]    last reason: 0/7: tensor 'idx' size mismatch at index 0. expected 13, actual 11
# W0810 18:44:08.304000 9563 torch/_dynamo/convert_frame.py:1358] [0/8] To log all recompilation reasons, use TORCH_LOGS="recompiles".
# W0810 18:44:08.304000 9563 torch/_dynamo/convert_frame.py:1358] [0/8] To diagnose recompilation issues, see https://pytorch.org/docs/main/torch.compiler_troubleshooting.html
#   batch_size=6 OK, peak memory: 11371 MiB
#
# Largest working --device-batch-size for depth=8, max-seq-len=2048: 6
# Peak memory at that batch size: 11371 MiB / 14912 MiB
